# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /Users/johnvijay/.pyenv/versions/3.10.0/lib/python3.10/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /Users/johnvijay/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from openpyxl) (1.1.0)
# WARNING: You are using pip version 21.2.3; however, version 23.0.1 is available.
# You should consider upgrading via the '/Users/johnvijay/.pyenv/versions/3.10.0/bin/python3.10 -m pip install --upgrade pip' command.

# %%
data = pd.read_csv('IS4250JanFeb2023.csv')

# %%
data = data.rename(columns={'Unnamed: 0': "Date"})
data.index = data['Date']
data = data.drop(columns = 'Date')
print(data.head())
print(data.shape)
# Out:
#                                 3-Jan-23  4-Jan-23  5-Jan-23  6-Jan-23  \
# Date
# Assessment                             4         4         1         1
# NIH Stroke Scale                       0         0         0         0
# Cogitive test (MMSE)                   3         2         1         0
# Montreal Cognitive Assessment          1         2         0         1
# Geriatric Depression Scale             0         0         0         0
#
#                                 9-Jan-23  10-Jan-23  11-Jan-23  12-Jan-23  \
# Date
# Assessment                            16          7          9          1
# NIH Stroke Scale                       0          0          0          0
# Cogitive test (MMSE)                  10          4          6          0
# Montreal Cognitive Assessment          4          2          1          1
# Geriatric Depression Scale             1          1          1          0
#
#                                 13-Jan-23  16-Jan-23  ...  16-Feb-23  \
# Date                                                  ...
# Assessment                              2         13  ...         13
# NIH Stroke Scale                        0          0  ...          0
# Cogitive test (MMSE)                    2          9  ...          6
# Montreal Cognitive Assessment           0          3  ...          6
# Geriatric Depression Scale              0          0  ...          0
#
#                                 17-Feb-23  20-Feb-23  21-Feb-23  22-Feb-23  \
# Date
# Assessment                              9          6          1          5
# NIH Stroke Scale                        0          0          0          0
# Cogitive test (MMSE)                    4          3          0          3
# Montreal Cognitive Assessment           5          3          1          2
# Geriatric Depression Scale              0          0          0          0
#
#                                 23-Feb-23  24-Feb-23  27-Feb-23  28-Feb-23  \
# Date
# Assessment                              3          0         11          2
# NIH Stroke Scale                        0          0          0          0
# Cogitive test (MMSE)                    2          0          2          2
# Montreal Cognitive Assessment           1          0          9          0
# Geriatric Depression Scale              0          0          0          0
#
#                                 Total
# Date
# Assessment                        241
# NIH Stroke Scale                    0
# Cogitive test (MMSE)              115
# Montreal Cognitive Assessment     111
# Geriatric Depression Scale          5
#
# [5 rows x 42 columns]
# (33, 42)

# %%
dataT = data.T
dataT.head()
# Out:
# Date      Assessment  NIH Stroke Scale    Cogitive test (MMSE)  \
# 3-Jan-23           4                   0                     3
# 4-Jan-23           4                   0                     2
# 5-Jan-23           1                   0                     1
# 6-Jan-23           1                   0                     0
# 9-Jan-23          16                   0                    10
#
# Date      Montreal Cognitive Assessment   Geriatric Depression Scale   \
# 3-Jan-23                               1                            0
# 4-Jan-23                               2                            0
# 5-Jan-23                               0                            0
# 6-Jan-23                               1                            0
# 9-Jan-23                               4                            1
#
# Date      Epworth Sleepiness Scale  Abbreviated Mental Test   \
# 3-Jan-23                         0                         0
# 4-Jan-23                         0                         0
# 5-Jan-23                         0                         0
# 6-Jan-23                         0                         0
# 9-Jan-23                         1                         0
#
# Date      Generalized Anxiety Questionnaire (GAD 7)  \
# 3-Jan-23                                          0
# 4-Jan-23                                          0
# 5-Jan-23                                          0
# 6-Jan-23                                          0
# 9-Jan-23                                          0
#
# Date      Neurological Disorder Depression Inventory for Epilepsy   \
# 3-Jan-23                                                  0
# 4-Jan-23                                                  0
# 5-Jan-23                                                  0
# 6-Jan-23                                                  0
# 9-Jan-23                                                  0
#
# Date      Unified Parkinson’s disease rating scale    ...  \
# 3-Jan-23                                           0  ...
# 4-Jan-23                                           0  ...
# 5-Jan-23                                           0  ...
# 6-Jan-23                                           0  ...
# 9-Jan-23                                           0  ...
#
# Date      Community resources  Others:  MAC Clinic (Non Resource)  \
# 3-Jan-23                    0        0                          0
# 4-Jan-23                    0        0                          0
# 5-Jan-23                    0        0                          0
# 6-Jan-23                    1        0                          0
# 9-Jan-23                    1        0                          0
#
# Date      Phone Call Follow Up  ACP  Referral  AIC  Dementia Singapore  SNSA  \
# 3-Jan-23                     0    0         0    0                   0     0
# 4-Jan-23                     0    0         1    1                   0     0
# 5-Jan-23                     0    0         0    0                   0     0
# 6-Jan-23                     0    0         0    0                   0     0
# 9-Jan-23                     0    0         0    0                   0     0
#
# Date      Total
# 3-Jan-23      4
# 4-Jan-23     10
# 5-Jan-23      7
# 6-Jan-23      7
# 9-Jan-23     24
#
# [5 rows x 33 columns]

# %%
plt.figure(figsize=(16, 8), dpi=150)
dataT['Total'].plot(label='Total', color='red')
plt.title('Number of referrals in Jan Plot')
plt.xlabel('Jan to Feb Patients')
plt.legend()

# %%
dataT["Date"] = dataT.index
dataT["Date"] = pd.to_datetime(dataT["Date"])
dataT.index = pd.to_datetime(dataT["Date"])
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "pandas/_libs/tslib.pyx", line 605, in pandas._libs.tslib.array_to_datetime
#   File "pandas/_libs/tslibs/parsing.pyx", line 318, in pandas._libs.tslibs.parsing.parse_datetime_string
#   File "/Users/johnvijay/.pyenv/versions/3.10.0/lib/python3.10/site-packages/dateutil/parser/_parser.py", line 1368, in parse
#     return DEFAULTPARSER.parse(timestr, **kwargs)
#   File "/Users/johnvijay/.pyenv/versions/3.10.0/lib/python3.10/site-packages/dateutil/parser/_parser.py", line 643, in parse
#     raise ParserError("Unknown string format: %s", timestr)
# dateutil.parser._parser.ParserError: Unknown string format: Total
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "pandas/_libs/tslib.pyx", line 616, in pandas._libs.tslib.array_to_datetime
# TypeError: invalid string coercion to datetime for "Total" at position 41
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/johnvijay/.pyenv/versions/3.10.0/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3460, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/k5/ywj_tkbj3vz4k8ywcp7bp75h0000gn/T/ipykernel_2042/3271447214.py", line 2, in <module>
#     dataT["Date"] = pd.to_datetime(dataT["Date"])
#   File "/Users/johnvijay/.pyenv/versions/3.10.0/lib/python3.10/site-packages/pandas/core/tools/datetimes.py", line 1068, in to_datetime
#     values = convert_listlike(arg._values, format)
#   File "/Users/johnvijay/.pyenv/versions/3.10.0/lib/python3.10/site-packages/pandas/core/tools/datetimes.py", line 438, in _convert_listlike_datetimes
#     result, tz_parsed = objects_to_datetime64ns(
#   File "/Users/johnvijay/.pyenv/versions/3.10.0/lib/python3.10/site-packages/pandas/core/arrays/datetimes.py", line 2177, in objects_to_datetime64ns
#     result, tz_parsed = tslib.array_to_datetime(
#   File "pandas/_libs/tslib.pyx", line 427, in pandas._libs.tslib.array_to_datetime
#   File "pandas/_libs/tslib.pyx", line 683, in pandas._libs.tslib.array_to_datetime
#   File "pandas/_libs/tslib.pyx", line 829, in pandas._libs.tslib._array_to_datetime_object
#   File "pandas/_libs/tslib.pyx", line 819, in pandas._libs.tslib._array_to_datetime_object
#   File "pandas/_libs/tslibs/parsing.pyx", line 318, in pandas._libs.tslibs.parsing.parse_datetime_string
#   File "/Users/johnvijay/.pyenv/versions/3.10.0/lib/python3.10/site-packages/dateutil/parser/_parser.py", line 1368, in parse
#     return DEFAULTPARSER.parse(timestr, **kwargs)
#   File "/Users/johnvijay/.pyenv/versions/3.10.0/lib/python3.10/site-packages/dateutil/parser/_parser.py", line 643, in parse
#     raise ParserError("Unknown string format: %s", timestr)
# dateutil.parser._parser.ParserError: Unknown string format: Total present at position 41
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/johnvijay/.pyenv/versions/3.10.0/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2057, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/Users/johnvijay/.pyenv/versions/3.10.0/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1288, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/Users/johnvijay/.pyenv/versions/3.10.0/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1177, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/Users/johnvijay/.pyenv/versions/3.10.0/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1049, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/Users/johnvijay/.pyenv/versions/3.10.0/lib/python3.10/site-packages/IPython/core/ultratb.py", line 935, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#   File "/Users/johnvijay/.pyenv/versions/3.10.0/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1003, in get_records
#     lines, first = inspect.getsourcelines(etb.tb_frame)
#   File "/Users/johnvijay/.pyenv/versions/3.10.0/lib/python3.10/inspect.py", line 1129, in getsourcelines
#     lines, lnum = findsource(object)
#   File "/Users/johnvijay/.pyenv/versions/3.10.0/lib/python3.10/inspect.py", line 958, in findsource
#     raise OSError('could not get source code')
# OSError: could not get source code

# %%
dataT

# %%
pip install pmdarima

# %%
from statsmodels.tsa.arima_model import ARIMA
import pmdarima as pm
model = pm.auto_arima(dataT.Total, start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
print(model.summary())

# %%
# Looking towards using ARIMA model to predict 
#https://pubmed.ncbi.nlm.nih.gov/34060654/ done in a similar prediction study for predicintg blood drawing in china 

from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

train = dataT.Total[:30]
test = dataT.Total[30:]
#print(test)
# 1,1,2 ARIMA Model
model = ARIMA(train, order=(2,1,0))
model_fit = model.fit()
arr = model_fit.predict( start = 30, end = 50, alpha=0.1, dynamic = True)  # 95% conf
#dataT[['Total','forecast']].plot(figsize=(12,8))
#print(arr)
#print(dataT.Total)
arr = round(arr)
print(arr)

arr.index = pd.to_datetime(arr.index)
plt.figure(figsize=(40,5), dpi=100)
plt.plot(dataT.Total, label='training')
plt.plot(arr, label='forecast')
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()


# # Make as pandas series
# fc_series = pd.Series(fc, index=test.index)
# lower_series = pd.Series(conf[:, 0], index=test.index)
# upper_series = pd.Series(conf[:, 1], index=test.index)

# # Plot
# plt.figure(figsize=(12,5), dpi=100)
# plt.plot(train, label='training')
# plt.plot(test, label='actual')
# plt.plot(fc_series, label='forecast')
# plt.fill_between(lower_series.index, lower_series, upper_series, 
#                  color='k', alpha=.15)
# plt.title('Forecast vs Actuals')
# plt.legend(loc='upper left', fontsize=8)
# plt.show()

# %%
print(arr.index)
arr.index = pd.to_datetime(arr.index)
print(arr.index)

# %%
##Estimating time 
newestimates = pd.DataFrame(arr)
newestimates = newestimates.rename(columns={'predicted_mean': "Estimate number of patient"})

#Frome excel data we find that Cogitive test (MMSE) consists of 33.92% of referral 
# and Montreal Cognitive Assessment consists of 32.74% of referrals
# rest is variance
newestimates['Estimated time taken in hours'] = newestimates['Estimate number of patient'] * (0.3392 * 15+ 0.3274 * 20 + 5/3) / 60

# %%
#Example of an estimate of 12 patient day
(12/3 * 15 + 12/3 * 20 + 12/3 * 5 )/ 60

# %%
newestimates
